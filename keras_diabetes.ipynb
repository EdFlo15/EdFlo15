# %% [markdown]
# <a href="https://colab.research.google.com/github/EdFlo15/EdFlo15/blob/main/keras_diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# load pima indians dataset
dataset = numpy.loadtxt('/content/drive/My Drive/datos/pima-indians-diabetes.csv', delimiter=",")

# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]
# Out:
# Mounted at /content/drive

# %%
# create model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu' ))
model.add(Dense(8 , activation='relu' ))
model.add(Dense(1 , activation='sigmoid' ))

# %%
# Compile model
model.compile(loss= 'binary_crossentropy' , optimizer= 'adam' , metrics=[ 'accuracy' ])

# %%
# Fit the model
model.fit(X, Y, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 77/77 [==============================] - 1s 1ms/step - loss: 4.4074 - accuracy: 0.5469
# Epoch 2/150
# 77/77 [==============================] - 0s 1ms/step - loss: 1.5339 - accuracy: 0.5508
# Epoch 3/150
# 77/77 [==============================] - 0s 1ms/step - loss: 1.1250 - accuracy: 0.5846
# Epoch 4/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.9889 - accuracy: 0.6042
# Epoch 5/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.8766 - accuracy: 0.6081
# Epoch 6/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.7848 - accuracy: 0.6276
# Epoch 7/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.8128 - accuracy: 0.6367
# Epoch 8/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.7422 - accuracy: 0.6667
# Epoch 9/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7641 - accuracy: 0.6458
# Epoch 10/150
# ...

# %%
# evaluate the model
scores = model.evaluate(X, Y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4562 - accuracy: 0.7734
# accuracy: 77.34%

# %%
## line end test github
