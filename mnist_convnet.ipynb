# %% [markdown]
# <a href="https://colab.research.google.com/github/EdFlo15/EdFlo15/blob/main/mnist_convnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simple MNIST convnet
#
# **Author:** [fchollet](https://twitter.com/fchollet)<br>
# **Date created:** 2015/06/19<br>
# **Last modified:** 2020/04/21<br>
# **Description:** A simple convnet that achieves ~99% test accuracy on MNIST.

# %% [markdown]
# ## Setup

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ## Prepare the data

# %%
# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")


# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %% [markdown]
# ## Build the model

# %%
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation="softmax"),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dropout (Dropout)           (None, 1600)              0
#
#  dense (Dense)               (None, 10)                16010
#
# =================================================================
# Total params: 34,826
# Trainable params: 34,826
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
batch_size = 128
epochs = 15

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Epoch 1/15
# 422/422 [==============================] - 39s 92ms/step - loss: 0.1239 - accuracy: 0.9627 - val_loss: 0.0588 - val_accuracy: 0.9830
# Epoch 2/15
# 422/422 [==============================] - 38s 91ms/step - loss: 0.0871 - accuracy: 0.9734 - val_loss: 0.0458 - val_accuracy: 0.9872
# Epoch 3/15
# 422/422 [==============================] - 38s 90ms/step - loss: 0.0735 - accuracy: 0.9775 - val_loss: 0.0430 - val_accuracy: 0.9878
# Epoch 4/15
# 422/422 [==============================] - 38s 91ms/step - loss: 0.0622 - accuracy: 0.9801 - val_loss: 0.0394 - val_accuracy: 0.9900
# Epoch 5/15
# 422/422 [==============================] - 40s 94ms/step - loss: 0.0563 - accuracy: 0.9831 - val_loss: 0.0354 - val_accuracy: 0.9903
# Epoch 6/15
# 422/422 [==============================] - 38s 91ms/step - loss: 0.0519 - accuracy: 0.9839 - val_loss: 0.0327 - val_accuracy: 0.9908
# Epoch 7/15
# 422/422 [==============================] - 38s 91ms/step - loss: 0.0469 - accuracy: 0.9854 - val_loss: 0.0323 - val_accuracy: 0.9912
# Epoch 8/15
# 422/422 [==============================] - 38s 91ms/step - loss: 0.0443 - accuracy: 0.9855 - val_loss: 0.0316 - val_accuracy: 0.9917
# Epoch 9/15
# 422/422 [==============================] - 38s 91ms/step - loss: 0.0414 - accuracy: 0.9865 - val_loss: 0.0312 - val_accuracy: 0.9918
# Epoch 10/15
# 422/422 [==============================] - 38s 91ms/step - loss: 0.0391 - accuracy: 0.9865 - val_loss: 0.0299 - val_accuracy: 0.9923
# Epoch 11/15
# 422/422 [==============================] - 38s 91ms/step - loss: 0.0369 - accuracy: 0.9879 - val_loss: 0.0305 - val_accuracy: 0.9918
# Epoch 12/15
# 422/422 [==============================] - 39s 91ms/step - loss: 0.0346 - accuracy: 0.9885 - val_loss: 0.0308 - val_accuracy: 0.9908
# Epoch 13/15
# 422/422 [==============================] - 38s 91ms/step - loss: 0.0341 - accuracy: 0.9891 - val_loss: 0.0298 - val_accuracy: 0.9915
# Epoch 14/15
# 422/422 [==============================] - 38s 91ms/step - loss: 0.0317 - accuracy: 0.9899 - val_loss: 0.0299 - val_accuracy: 0.9918
# Epoch 15/15
# 422/422 [==============================] - 38s 91ms/step - loss: 0.0310 - accuracy: 0.9896 - val_loss: 0.0265 - val_accuracy: 0.9927

# %% [markdown]
# ## Evaluate the trained model

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.023562351241707802
# Test accuracy: 0.9912999868392944
